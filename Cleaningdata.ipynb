# %% [markdown]
# <a href="https://colab.research.google.com/github/ssonjaaaa/DATA-CRAWLING/blob/main/Cleaningdata.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as UKT_csv

# %%
df = pd.read_csv('/content/UKT.csv')
df.head()
# Out:
#    conversation_id_str                      created_at  favorite_count  \
# 0  1795504263797375052  Tue May 28 17:15:50 +0000 2024           20773
# 1  1666763250627928067  Thu Jun 08 11:05:00 +0000 2023           14975
# 2  1787084005361541564  Sun May 05 11:36:43 +0000 2024            5950
# 3  1573137677876359169  Fri Sep 23 02:30:24 +0000 2022            4924
# 4  1666647486340161537  Thu Jun 08 03:25:00 +0000 2023           16063
#
#                                            full_text               id_str  \
# 0  Gara-gara kasus akhir-akhir ini kayak Bea Cuka...  1795504263797375052
# 1  ‍ tipe tipe reaksi anak pns ketika penetapan u...  1666763250627928067
# 2  Merekrut-melatih guru2 dgn followers tiktok &a...  1787084005361541564
# 3         Ameh bayar ukt mas https://t.co/LKFTaoHxzC  1573137677876359169
# 4  ‍ temen sender ngeluh anak pns dapet ukt terti...  1666647486340161537
#
#                                            image_url in_reply_to_screen_name  \
# ...

# %%
# prompt: cleaningkan data saya

# Check for missing values
print(df.isnull().sum())

# Handle missing values (replace with mean, median, or remove rows/columns)
# Example: Replace missing values in 'column_name' with the mean
# df['column_name'].fillna(df['column_name'].mean(), inplace=True)

# Remove duplicate rows
df.drop_duplicates(inplace=True)

# Convert data types if needed
# Example: Convert 'column_name' to numeric
# df['column_name'] = pd.to_numeric(df['column_name'])

# Remove irrelevant columns
# df.drop(['column_name1', 'column_name2'], axis=1, inplace=True)

# Check for outliers (using box plots, z-scores, etc.)
# Example: Remove outliers in 'column_name' using z-scores
# from scipy import stats
# z = np.abs(stats.zscore(df['column_name']))
# df = df[(z < 3)]

# You can add more cleaning steps based on your specific needs.
# For example, you might want to normalize or standardize your data,
# or you might want to handle inconsistent data entries.

# Print the cleaned dataframe
print(df.head())
# Out:
# conversation_id_str          0
# created_at                   0
# favorite_count               0
# full_text                    0
# id_str                       0
# image_url                  180
# in_reply_to_screen_name    175
# lang                         0
# location                    86
# quote_count                  0
# reply_count                  0
# retweet_count                0
# tweet_url                    0
# user_id_str                  0
# username                     0
# dtype: int64
#    conversation_id_str                      created_at  favorite_count  \
# 0  1795504263797375052  Tue May 28 17:15:50 +0000 2024           20773
# 1  1666763250627928067  Thu Jun 08 11:05:00 +0000 2023           14975
# 2  1787084005361541564  Sun May 05 11:36:43 +0000 2024            5950
# 3  1573137677876359169  Fri Sep 23 02:30:24 +0000 2022            4924
# 4  1666647486340161537  Thu Jun 08 03:25:00 +0000 2023           16063
#
# ...

# %%
# prompt: data duplicat

# Find duplicate rows based on all columns
duplicate_rows = df[df.duplicated()]

# Print the duplicate rows
print("Duplicate Rows:")
print(duplicate_rows)

# Remove duplicate rows (keeping the first occurrence)
df.drop_duplicates(inplace=True)

# Print the DataFrame after removing duplicates
print("\nDataFrame after removing duplicates:")
print(df.head())
# Out:
# Duplicate Rows:
# Empty DataFrame
# Columns: [conversation_id_str, created_at, favorite_count, full_text, id_str, image_url, in_reply_to_screen_name, lang, location, quote_count, reply_count, retweet_count, tweet_url, user_id_str, username]
# Index: []
#
# DataFrame after removing duplicates:
#    conversation_id_str                      created_at  favorite_count  \
# 0  1795504263797375052  Tue May 28 17:15:50 +0000 2024           20773
# 1  1666763250627928067  Thu Jun 08 11:05:00 +0000 2023           14975
# 2  1787084005361541564  Sun May 05 11:36:43 +0000 2024            5950
# 3  1573137677876359169  Fri Sep 23 02:30:24 +0000 2022            4924
# 4  1666647486340161537  Thu Jun 08 03:25:00 +0000 2023           16063
#
#                                            full_text               id_str  \
# 0  Gara-gara kasus akhir-akhir ini kayak Bea Cuka...  1795504263797375052
# 1  ‍ tipe tipe reaksi anak pns ketika penetapan u...  1666763250627928067
# ...

# %%
# prompt: data missing values

# Check for missing values in each column
missing_values = df.isnull().sum()

# Print the number of missing values for each column
print("Missing Values per Column:")
print(missing_values)

# Calculate the percentage of missing values for each column
missing_percentage = (df.isnull().sum() / len(df)) * 100

# Print the percentage of missing values for each column
print("\nPercentage of Missing Values per Column:")
print(missing_percentage)
# Out:
# Missing Values per Column:
# conversation_id_str          0
# created_at                   0
# favorite_count               0
# full_text                    0
# id_str                       0
# image_url                  180
# in_reply_to_screen_name    175
# lang                         0
# location                    86
# quote_count                  0
# reply_count                  0
# retweet_count                0
# tweet_url                    0
# user_id_str                  0
# username                     0
# dtype: int64
#
# Percentage of Missing Values per Column:
# conversation_id_str         0.000000
# created_at                  0.000000
# favorite_count              0.000000
# full_text                   0.000000
# id_str                      0.000000
# image_url                  75.313808
# in_reply_to_screen_name    73.221757
# lang                        0.000000
# location                   35.983264
# quote_count                 0.000000
# ...

# %%
# prompt: hapus kolom missing value

# Remove columns with any missing values
df.dropna(axis=1, inplace=True)

# Print the DataFrame after removing columns with missing values
print("\nDataFrame after removing columns with missing values:")
print(df.head())
# Out:
# DataFrame after removing columns with missing values:
#    conversation_id_str                      created_at  favorite_count  \
# 0  1795504263797375052  Tue May 28 17:15:50 +0000 2024           20773
# 1  1666763250627928067  Thu Jun 08 11:05:00 +0000 2023           14975
# 2  1787084005361541564  Sun May 05 11:36:43 +0000 2024            5950
# 3  1573137677876359169  Fri Sep 23 02:30:24 +0000 2022            4924
# 4  1666647486340161537  Thu Jun 08 03:25:00 +0000 2023           16063
#
#                                            full_text               id_str  \
# 0  Gara-gara kasus akhir-akhir ini kayak Bea Cuka...  1795504263797375052
# 1  ‍ tipe tipe reaksi anak pns ketika penetapan u...  1666763250627928067
# 2  Merekrut-melatih guru2 dgn followers tiktok &a...  1787084005361541564
# 3         Ameh bayar ukt mas https://t.co/LKFTaoHxzC  1573137677876359169
# 4  ‍ temen sender ngeluh anak pns dapet ukt terti...  1666647486340161537
#
# ...

# %%
# prompt: tampilkan semua data yang sudah dicleaning

print(df)
# Out:
#      conversation_id_str                      created_at  favorite_count  \
# 0    1795504263797375052  Tue May 28 17:15:50 +0000 2024           20773
# 1    1666763250627928067  Thu Jun 08 11:05:00 +0000 2023           14975
# 2    1787084005361541564  Sun May 05 11:36:43 +0000 2024            5950
# 3    1573137677876359169  Fri Sep 23 02:30:24 +0000 2022            4924
# 4    1666647486340161537  Thu Jun 08 03:25:00 +0000 2023           16063
# ..                   ...                             ...             ...
# 234  1841028229785677859  Tue Oct 01 08:11:49 +0000 2024               1
# 235  1841856318933762073  Thu Oct 03 18:02:01 +0000 2024              93
# 236  1841274182463840713  Wed Oct 02 00:29:08 +0000 2024               2
# 237  1841856318933762073  Fri Oct 04 02:12:17 +0000 2024             716
# 238  1841022805090984313  Tue Oct 01 12:52:22 +0000 2024               3
#
#                                              full_text               id_str  \
# ...
